# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import rc
rc('text', usetex=False)
# %matplotlib inline

# %%
x = np.linspace(0,10,100)
# plt.plot(x, x**2)
# plt.plot(x, x**3)
# plt.plot(x, x**(1/2))
# plt.figure()
plt.subplot(2,2,1)
plt.plot(x, np.sin(x))
plt.subplot(2,2,2)
plt.plot(x, np.cos(x))
plt.subplot(2,2,3)
plt.plot(x)
plt.subplot(2,2,4)
plt.plot(-x)
# plt.subplot(3,1,2)
# plt.plot(x, np.cos(x))
# plt.subplot(3,2,2)
# plt.plot(x, np.cosh(x))
# plt.subplot(3,1,1)
# plt.plot(x, np.cosh(x))
plt.show()

# seri=pd.Series(x)
# seri.plot()

# %%
import pandas as pd

df = pd.DataFrame({
    'name':['john','mary','peter','jeff','bill','lisa','jose'],
    'age':[23,78,22,19,45,33,20],
    'gender':['M','F','M','M','M','F','M'],
    'state':['california','dc','california','dc','california','texas','texas'],
    "num_of_children":[2,0,0,3,2,1,4],
    'numofpets':[5,1,0,5,2,2,3]
})
df
# Out:
#     name  age gender       state  num_of_children  numofpets
# 0   john   23      M  california                2          5
# 1   mary   78      F          dc                0          1
# 2  peter   22      M  california                0          0
# 3   jeff   19      M          dc                3          5
# 4   bill   45      M  california                2          2
# 5   lisa   33      F       texas                1          2
# 6   jose   20      M       texas                4          3

# %%
df.plot(kind='bar', x='name', y='age')
df.plot()

# %%
a, b = plt.subplots(4)
print(type(a))
list(b)
b[1].plot(x, np.sin(x))
# Out:
# <class 'matplotlib.figure.Figure'>

# %%
plt.style.use('seaborn-whitegrid')

# %%
fig=plt.figure()
ax=plt.axes()
x=np.linspace(0,10,500)
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x))

# %%
x=np.linspace(-20,20,50)
x2=x*10
y=x**2 + 2*x -2
plt.plot(x,y,color='red', marker='o')
plt.plot(x2,y, color='blue', linestyle='dashed')
plt.xlabel('ini x')
plt.ylabel('ini y')
plt.legend(['test', 'anu'])
plt.title('ini adalah judul')
# Out:
# Text(0.5, 1.0, 'ini adalah judul')

# %%
fig=plt.figure()

ax=fig.add_axes([0.1, 0.1, 0.8, 0.8])
