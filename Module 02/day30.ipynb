# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# %%
df = pd.DataFrame({
    'x': [0,1,2,3,4],
    'y': [0,1,4,9,16],
    'z': [0,1,10,19,36]
})
x=np.linspace(0,10,25)
y=np.sin(x)
z=np.cos(x)
# plt.plot(x,y,x,z)plt.
plt.plot(x,y)
plt.plot(x,z)
plt.grid()
# plt.xticks(np.arange(6))
plt.yticks(rotation=45)
plt.title('Test Chart')
# Out:
# Text(0.5, 1.0, 'Test Chart')

# %%
plt.figure('Test',figsize=(7,7))
plt.subplot(221)
plt.plot([1,2,3],[4,5,6])
plt.title('Test')

plt.subplot(222)
plt.plot([1,2,3],[9,10,11])
plt.title('Test')

plt.subplot(223)
plt.plot([1,2,3],[9,10,11])
plt.title('Test2')

plt.suptitle('Belum makan')

plt.figure('Makan', figsize=(7,7))
plt.subplot(221)
plt.plot(df['x'], df[['y', 'z']])
plt.title('Test satu')

plt.subplot(222)
plt.plot(df['x'], df['z'])
plt.title('Test dua')

plt.subplot(223)
plt.plot(df['x'], df['y'])
plt.title('Test tiga')

plt.subplot(224)
plt.bar([1,2,3],[9,10,11])
plt.title('Test Empat')
plt.suptitle('Sudah Makan')
# Out:
# Text(0.5, 0.98, 'Sudah Makan')

# %%
x1 = np.array([i for i in range(10)])
y1=x1 ** 2
z1=x1+7
plt.bar(x1,y1)
plt.bar(x1,z1)

plt.title('Ini Bar Chart', fontdict={
    'family':'comic sans ms',
    'size': 30,
    'color': 'lightgreen'
})
plt.xlabel('X Value')
plt.ylabel('y = sin(x)')
for i, j in zip(x1,y1):
    plt.text(i-0.5,j+4, f'({i},{j})')

# %%
import numpy as np
import matplotlib.pyplot as plt

# data to plot
n_groups = 4
means_frank = (90, 55, 40, 65)
means_guido = (85, 62, 54, 20)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.8

rects1 = plt.bar(index, means_frank, bar_width,
alpha=opacity,
color='b',
label='Frank')

rects2 = plt.bar(index + bar_width, means_guido, bar_width,
alpha=opacity,
color='g',
label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')
plt.xticks(index + bar_width, ('A', 'B', 'C', 'D'))
plt.legend()

plt.tight_layout()
plt.show()

# %%
x1 = np.array([i for i in range(10)])
y1=x1 ** 2
z1=x1+7
a=np.array([1,2,3,4,5])
plt.bar(a,[6,7,8,9,10], 0.4, label='makan nasi')
plt.bar(a+0.4, [11,12,13,14,8], 0.4, label='belum makan')
plt.tight_layout()
plt.legend()
plt.xticks(a+(0.4/2), list('ABCDE'))
plt.show()

# %%
a=np.random.rand(100)
b=np.random.rand(100)
c=np.random.rand(100)
plt.scatter(a,b, label='A')
plt.scatter(a,c, label='B')
plt.scatter(b,c, label='C')
plt.legend(loc='upper right', ncol=3)

# %%
a=np.random.randint(1,20, 20)
b=np.random.randint(1,20,20)
plt.scatter(a,b)
plt.show()

# %%
plt.plot([1,2,3],[4,5,6], 'g', markersize=20, zorder=2)
plt.scatter([1,2,3],[4,5,6], marker='$wow$', s=1000, color='y',edgecolors='r',zorder=3),
plt.bar([1,2,3],[4,5,6], zorder=1)
plt.xlabel('ini X')
plt.ylabel('ini Y')
plt.title('ini TITLE')
plt.show()

# %%
a=np.random.randint(1,10,11)
b=[f'angka {str(i)}' for i in a]
plt.pie(a, labels=b)

plt.show()

# %%
persentase = [25,25,20,30]
keterangan = ['A', 'B', 'C', 'D']
plt.pie(persentase, labels=keterangan, colors=['r', 'y', 'b', 'pink'], startangle=45, shadow=True, counterclock=False, explode=(0.1,0.1,0.1,0.1))
plt.show()

# %%
usia = np.random.randint(20,65,25)
# usia = np.array([32, 47, 33, 30, 25, 22, 35, 21, 43, 49, 23, 49, 43, 31, 39])
usia2=np.random.randint(20,65,20)
usia3=np.random.randint(20,65,25)
partisi=np.arange(20,66,5)
plt.hist([usia, usia2, usia3], partisi)
plt.xticks(partisi)
plt.show()

# %%
test=np.random.randint(20,65,1000).reshape(10,10,10)
test
# Out:
# array([[[41, 43, 43, 62, 62, 37, 57, 53, 25, 30],
#         [31, 30, 31, 45, 62, 40, 24, 30, 59, 33],
#         [63, 52, 23, 30, 36, 40, 41, 57, 28, 23],
#         [27, 30, 62, 40, 48, 55, 41, 35, 26, 60],
#         [35, 20, 51, 53, 31, 37, 49, 61, 20, 35],
#         [64, 34, 24, 59, 30, 45, 57, 28, 43, 59],
#         [62, 34, 58, 43, 24, 61, 29, 64, 42, 50],
#         [39, 49, 53, 61, 62, 40, 48, 30, 59, 44],
#         [51, 33, 24, 35, 25, 26, 31, 55, 27, 57],
#         [20, 25, 32, 42, 51, 41, 31, 51, 35, 61]],
#
#        [[51, 46, 56, 60, 54, 51, 31, 44, 39, 54],
#         [33, 43, 27, 38, 47, 41, 43, 45, 26, 57],
#         [52, 47, 37, 25, 42, 26, 62, 20, 54, 23],
#         [60, 23, 53, 22, 23, 21, 53, 55, 53, 40],
#         [29, 63, 29, 26, 39, 39, 34, 58, 44, 59],
#         [51, 51, 51, 60, 52, 47, 34, 28, 51, 61],
#         [62, 53, 59, 25, 25, 64, 31, 41, 49, 23],
#         [22, 22, 30, 38, 48, 27, 35, 34, 43, 24],
#         [48, 26, 43, 22, 54, 32, 33, 45, 64, 47],
# ...

# %%
import matplotlib.image as mimg
gbr=mimg.imread('misc/test.png')[:,:,:]
print(gbr.shape)
plt.imshow(gbr)
plt.colorbar()
plt.show()

print(gbr[756,333])
# Out:
# (800, 480, 4)
# [1. 1. 1. 1.]

# %%
k=np.array([[
    [1,2,3,5],
    [4,5,6,6],
    # [99,98,97,96]
],[
    [7,8,9,11],
    [10,11,12,13]
],[
    [15,16,17,18],
    [20,22,23,14]
]])

print(k)
print("")
print(k.shape)
print("")
print(k[1])
# Out:
# [[[ 1  2  3  5]
#   [ 4  5  6  6]]
#
#  [[ 7  8  9 11]
#   [10 11 12 13]]
#
#  [[15 16 17 18]
#   [20 22 23 14]]]
#
# (3, 2, 4)
#
# [[ 7  8  9 11]
#  [10 11 12 13]]
